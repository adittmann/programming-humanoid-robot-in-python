# %% [markdown]
# # Robot Arm Kinematics (2D)

# %%
# %matplotlib inline
from pylab import *
from numpy import sin, cos, pi, matrix, random
from __future__ import division
from math import atan2
rcParams['figure.figsize'] = 12, 10  # that's default image size for this interactive session
from IPython import display
from IPython.html.widgets import interact, fixed
# Out:
# /home/alex/.local/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Coordinate Transformation

# %%
def trans(x, y, a):
    '''create a 2D transformation'''
    s = sin(a)
    c = cos(a)
    return matrix([[c, -s, x],
                   [s,  c, y],
                   [0,  0, 1]])

def from_trans(m):
    '''get x, y, theta from transform matrix'''
    return [m[0, -1], m[1, -1], atan2(m[1, 0], m[0, 0])]

# %%
trans(0, 0, 0)
# Out:
# matrix([[ 1., -0.,  0.],
#         [ 0.,  1.,  0.],
#         [ 0.,  0.,  1.]])

# %% [markdown]
# ## Parameters of robot arm

# %%
N = 3  # number of links
l = [0] + range(N, 0, -1)  # length of link, l[0] is ingored
max_len = sum(l)
a = random.random_sample(N)  # angles of joints
T0 = trans(0, 0, 0)  # base

# %% [markdown]
# ## Forward Kinematics

# %%
def forward_kinematics(T0, l, a):
    T = [T0]
    for i in range(len(a)):
        Ti = T[-1] * trans(l[i], 0, a[i])
        T.append(Ti)
    Te = T[-1] * trans(l[-1], 0, 0)  # end effector
    T.append(Te)
    return T

# %%
def show_robot_arm(T):
    cla()
    x = [Ti[0,-1] for Ti in T]
    y = [Ti[1,-1] for Ti in T]
    plot(x, y, '-or', linewidth=5, markersize=10)
    xlim([-max_len, max_len])
    ylim([-max_len, max_len]) 
    ax = axes()
    ax.set_aspect('equal')
    t = atan2(T[-1][1, 0], T[-1][0,0])
    ax.annotate('[%f,%f,%f]' % (x[-1], y[-1], t), xy=(x[-1], y[-1]), xytext=(x[-1], y[-1] + 0.5))
    display.clear_output(wait=True)

# %%
for i in range(N):
    @interact(value=(-pi/2, pi/2, 0.1), n=fixed(i))
    def set_joint_angle(n, value=0):
        global a
        a[n] = value
        T = forward_kinematics(T0, l, a)
        show_robot_arm(T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c26ddcb70d6c> in set_joint_angle(n, value)
#       5         a[n] = value
#       6         T = forward_kinematics(T0, l, a)
# ----> 7         show_robot_arm(T)
#
# <ipython-input-6-6257112ef219> in show_robot_arm(T)
#       3     x = [Ti[0,-1] for Ti in T]
#       4     y = [Ti[1,-1] for Ti in T]
# ----> 5     plot(x, y, '-or', linewidth=5, markersize=10)
#       6     xlim([-max_len, max_len])
#       7     ylim([-max_len, max_len])
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1373
#    1374         for line in self._get_lines(*args, **kwargs):
# -> 1375             self.add_line(line)
#    1376             lines.append(line)
#    1377
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in add_line(self, line)
#    1484             line.set_clip_path(self.patch)
#    1485
# -> 1486         self._update_line_limits(line)
#    1487         if not line.get_label():
#    1488             line.set_label('_line%d' % len(self.lines))
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in _update_line_limits(self, line)
#    1495         Figures out the data limit of the given line, updating self.dataLim.
#    1496         """
# -> 1497         path = line.get_path()
#    1498         if path.vertices.size == 0:
#    1499             return
#
# /usr/lib/python2.7/dist-packages/matplotlib/lines.pyc in get_path(self)
#     869         """
#     870         if self._invalidy or self._invalidx:
# --> 871             self.recache()
#     872         return self._path
#     873
#
# /usr/lib/python2.7/dist-packages/matplotlib/lines.pyc in recache(self, always)
#     570                 x = ma.asarray(xconv, np.float_)
#     571             else:
# --> 572                 x = np.asarray(xconv, np.float_)
#     573             x = x.ravel()
#     574         else:
#
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/expr.pyc in __float__(self)
#     218         # to fail, and if it is we still need to check that it evalf'ed to
#     219         # a number.
# --> 220         result = self.evalf()
#     221         if result.is_Number:
#     222             return float(result)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/evalf.pyc in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1307         if not evalf_table:
#    1308             _create_evalf_table()
# -> 1309         prec = dps_to_prec(n)
#    1310         options = {'maxprec': max(prec, int(maxn*LG10)), 'chop': chop,
#    1311                'strict': strict, 'verbose': verbose}
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/mpmath/libmp/libmpf.pyc in dps_to_prec(n)
#      65     """Return the number of bits required to represent n decimals
#      66     accurately."""
# ---> 67     return max(1, int(round((int(n)+1)*3.3219280948873626)))
#      68
#      69 def repr_dps(n):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/expr.pyc in __float__(self)
#     218         # to fail, and if it is we still need to check that it evalf'ed to
#     219         # a number.
# --> 220         result = self.evalf()
#     221         if result.is_Number:
#     222             return float(result)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/evalf.pyc in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1307         if not evalf_table:
#    1308             _create_evalf_table()
# -> 1309         prec = dps_to_prec(n)
#    1310         options = {'maxprec': max(prec, int(maxn*LG10)), 'chop': chop,
#    1311                'strict': strict, 'verbose': verbose}
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/mpmath/libmp/libmpf.pyc in dps_to_prec(n)
#      65     """Return the number of bits required to represent n decimals
#      66     accurately."""
# ---> 67     return max(1, int(round((int(n)+1)*3.3219280948873626)))
#      68
#      69 def repr_dps(n):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/expr.pyc in __float__(self)
#     218         # to fail, and if it is we still need to check that it evalf'ed to
#     219         # a number.
# --> 220         result = self.evalf()
#     221         if result.is_Number:
#     222             return float(result)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/evalf.pyc in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1307         if not evalf_table:
#    1308             _create_evalf_table()
# -> 1309         prec = dps_to_prec(n)
#    1310         options = {'maxprec': max(prec, int(maxn*LG10)), 'chop': chop,
#    1311                'strict': strict, 'verbose': verbose}
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/mpmath/libmp/libmpf.pyc in dps_to_prec(n)
#      65     """Return the number of bits required to represent n decimals
#      66     accurately."""
# ---> 67     return max(1, int(round((int(n)+1)*3.3219280948873626)))
#      68
#      69 def repr_dps(n):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/core/expr.pyc in __float__(self)
#     223         if result.is_number and result.as_real_imag()[1]:
#     224             raise TypeError("can't convert complex to float")
# --> 225         raise TypeError("can't convert expression to float")
#     226
#     227     def __complex__(self):
#
# TypeError: can't convert expression to float

# %% [markdown]
# ## Inverse Kinematics

# %% [markdown]
# ## Analytical Solutions with Sympy

# %% [markdown]
# [SymPy](http://sympy.org/) is a Python library for symbolic mathematics.

# %%
from sympy import init_printing, sin, cos, pi, asin, acos, atan2, atan, sqrt, simplify, solve, latex, symbols
from sympy import Matrix as matrix
init_printing()

# %%
from sympy.abc import x, y, theta
trans(x, y, theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}\cos{\left (\theta \right )} & - \sin{\left (\theta \right )} & x\\\sin{\left (\theta \right )} & \cos{\left (\theta \right )} & y\\0 & 0 & 1\end{smallmatrix}\right]
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡cos(θ)  -sin(θ)  x⎤
# ⎢                  ⎥
# ⎢sin(θ)  cos(θ)   y⎥
# ⎢                  ⎥
# ⎣  0        0     1⎦

# %%
N = 4
l = [symbols('l_%d' % i) for i in range(N + 1)]
l[0] = 0
a = [symbols('theta_%d' % i) for i in range(N)]
T0 = trans(0, 0, 0)

# %%
l, a
# Out:
# ([0, l₁, l₂, l₃, l₄], [θ₀, θ₁, θ₂, θ₃])

# %%
T0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}1 & 0 & 0\\0 & 1 & 0\\0 & 0 & 1\end{smallmatrix}\right]
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
T = forward_kinematics(T0, l, a)
Te = T[-1]
Te
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}\left(- \left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \sin{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \cos{\left (\theta_{2} \right )}\right) \sin{\left (\theta_{3} \right )} + \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \cos{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \sin{\left (\theta_{2} \right )}\right) \cos{\left (\theta_{3} \right )} & \left(- \left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \sin{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \cos{\left (\theta_{2} \right )}\right) \cos{\left (\theta_{3} \right )} - \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \cos{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \sin{\left (\theta_{2} \right )}\right) \sin{\left (\theta_{3} \right )} & l_{1} \cos{\left (\theta_{0} \right )} + l_{2} \left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) + l_{3} \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \cos{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \sin{\left (\theta_{2} \right )}\right) + l_{4} \left(\left(- \left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \sin{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \cos{\left (\theta_{2} \right )}\right) \sin{\left (\theta_{3} \right )} + \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \cos{\left (\theta_{2} \right )} + \left(- \sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} - \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \sin{\left (\theta_{2} \right )}\right) \cos{\left (\theta_{3} \right )}\right)\\\left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \sin{\left (\theta_{2} \right )} + \left(\sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} + \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \cos{\left (\theta_{2} \right )}\right) \cos{\left (\theta_{3} \right )} + \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\left (\theta_{1} \right )} + \cos{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )}\right) \cos{\left (\theta_{2} \right )} - \left(\sin{\left (\theta_{0} \right )} \cos{\left (\theta_{1} \right )} + \sin{\left (\theta_{1} \right )} \cos{\left (\theta_{0} \right )}\right) \sin{\left (\theta_{2} \right )}\right) \sin{\left (\theta_{3} \right )} & - \left(\left(- \sin{\left (\theta_{0} \right )} \sin{\lef ...
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡(-(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅
# ⎢
# ⎢ ((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅c
# ⎢
# ⎣
#
# cos(θ₀))⋅cos(θ₂))⋅sin(θ₃) + ((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-
#
# os(θ₀))⋅cos(θ₂))⋅cos(θ₃) + ((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) - (si
#
#                          0
#
# sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅cos(θ₀))⋅sin(θ₂))⋅cos(θ₃)  (-(-sin(θ₀)⋅sin(θ₁) + cos
#
# n(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos(θ₀))⋅sin(θ₂))⋅sin(θ₃)     -((-sin(θ₀)⋅sin(θ₁) + co
#
#
#
# (θ₀)⋅cos(θ₁))⋅sin(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅cos(θ₀))⋅cos(θ₂))⋅cos(θ₃)
#
# s(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos(θ₀))⋅cos(θ₂))⋅sin(θ₃)
#
#                                                                              0
#
# - ((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅
#
# + ((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) - (sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅c
#
#
#
# cos(θ₀))⋅sin(θ₂))⋅sin(θ₃)  l₁⋅cos(θ₀) + l₂⋅(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁)
#
# os(θ₀))⋅sin(θ₂))⋅cos(θ₃)     l₁⋅sin(θ₀) + l₂⋅(sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos(θ₀
#
#
#
# ) + l₃⋅((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin
#
# )) + l₃⋅((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (sin(θ₀)⋅cos(θ₁) + sin
#
#
#
# (θ₁)⋅cos(θ₀))⋅sin(θ₂)) + l₄⋅((-(-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) +
#
# (θ₁)⋅cos(θ₀))⋅cos(θ₂)) + l₄⋅(((-sin(θ₀)⋅sin(θ₁) + cos(θ₀)⋅cos(θ₁))⋅sin(θ₂) + (
#
#                                                      1
#
# (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅cos(θ₀))⋅cos(θ₂))⋅sin(θ₃) + ((-sin(θ₀)⋅sin(θ₁) + c
#
# sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos(θ₀))⋅cos(θ₂))⋅cos(θ₃) + ((-sin(θ₀)⋅sin(θ₁) + cos
#
#
#
# os(θ₀)⋅cos(θ₁))⋅cos(θ₂) + (-sin(θ₀)⋅cos(θ₁) - sin(θ₁)⋅cos(θ₀))⋅sin(θ₂))⋅cos(θ₃
#
# (θ₀)⋅cos(θ₁))⋅cos(θ₂) - (sin(θ₀)⋅cos(θ₁) + sin(θ₁)⋅cos(θ₀))⋅sin(θ₂))⋅sin(θ₃))
#
#
#
# ))⎤
#   ⎥
#   ⎥
#   ⎥
#   ⎦

# %%
Te = simplify(Te)
Te
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}\cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} & - \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} & l_{1} \cos{\left (\theta_{0} \right )} + l_{2} \cos{\left (\theta_{0} + \theta_{1} \right )} + l_{3} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} \right )} + l_{4} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )}\\\sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} & \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} & l_{1} \sin{\left (\theta_{0} \right )} + l_{2} \sin{\left (\theta_{0} + \theta_{1} \right )} + l_{3} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} \right )} + l_{4} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )}\\0 & 0 & 1\end{smallmatrix}\right]
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡cos(θ₀ + θ₁ + θ₂ + θ₃)  -sin(θ₀ + θ₁ + θ₂ + θ₃)  l₁⋅cos(θ₀) + l₂⋅cos(θ₀ + θ₁)
# ⎢
# ⎢sin(θ₀ + θ₁ + θ₂ + θ₃)  cos(θ₀ + θ₁ + θ₂ + θ₃)   l₁⋅sin(θ₀) + l₂⋅sin(θ₀ + θ₁)
# ⎢
# ⎣          0                        0
#
#  + l₃⋅cos(θ₀ + θ₁ + θ₂) + l₄⋅cos(θ₀ + θ₁ + θ₂ + θ₃)⎤
#                                                    ⎥
#  + l₃⋅sin(θ₀ + θ₁ + θ₂) + l₄⋅sin(θ₀ + θ₁ + θ₂ + θ₃)⎥
#                                                    ⎥
#            1                                       ⎦

# %%
eq = Te * trans(x, y, theta).inv() - T0
eq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}\left(- \frac{\sin^{2}{\left (\theta \right )}}{\cos{\left (\theta \right )}} + \frac{1}{\cos{\left (\theta \right )}}\right) \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} + \sin{\left (\theta \right )} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} - 1 & \sin{\left (\theta \right )} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} - \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} \cos{\left (\theta \right )} & l_{1} \cos{\left (\theta_{0} \right )} + l_{2} \cos{\left (\theta_{0} + \theta_{1} \right )} + l_{3} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} \right )} + l_{4} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} + \left(- \frac{x}{\cos{\left (\theta \right )}} - \left(- \frac{x \sin{\left (\theta \right )}}{\cos{\left (\theta \right )}} + y\right) \sin{\left (\theta \right )}\right) \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} + \left(- \frac{x \sin{\left (\theta \right )}}{\cos{\left (\theta \right )}} + y\right) \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} \cos{\left (\theta \right )}\\\left(- \frac{\sin^{2}{\left (\theta \right )}}{\cos{\left (\theta \right )}} + \frac{1}{\cos{\left (\theta \right )}}\right) \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} - \sin{\left (\theta \right )} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} & \sin{\left (\theta \right )} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} + \cos{\left (\theta \right )} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} - 1 & l_{1} \sin{\left (\theta_{0} \right )} + l_{2} \sin{\left (\theta_{0} + \theta_{1} \right )} + l_{3} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} \right )} + l_{4} \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} + \left(- \frac{x}{\cos{\left (\theta \right )}} - \left(- \frac{x \sin{\left (\theta \right )}}{\cos{\left (\theta \right )}} + y\right) \sin{\left (\theta \right )}\right) \sin{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )} - \left(- \frac{x \sin{\left (\theta \right )}}{\cos{\left (\theta \right )}} + y\right) \cos{\left (\theta \right )} \cos{\left (\theta_{0} + \theta_{1} + \theta_{2} + \theta_{3} \right )}\\0 & 0 & 0\end{smallmatrix}\right]
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡⎛     2            ⎞
# ⎢⎜  sin (θ)     1   ⎟
# ⎢⎜- ─────── + ──────⎟⋅cos(θ₀ + θ₁ + θ₂ + θ₃) + sin(θ)⋅sin(θ₀ + θ₁ + θ₂ + θ₃) -
# ⎢⎝   cos(θ)   cos(θ)⎠
# ⎢
# ⎢  ⎛     2            ⎞
# ⎢  ⎜  sin (θ)     1   ⎟
# ⎢  ⎜- ─────── + ──────⎟⋅sin(θ₀ + θ₁ + θ₂ + θ₃) - sin(θ)⋅cos(θ₀ + θ₁ + θ₂ + θ₃)
# ⎢  ⎝   cos(θ)   cos(θ)⎠
# ⎢
# ⎣                                       0
#
#
#
#  1    sin(θ)⋅cos(θ₀ + θ₁ + θ₂ + θ₃) - sin(θ₀ + θ₁ + θ₂ + θ₃)⋅cos(θ)    l₁⋅cos(
#
#
#
#
#     sin(θ)⋅sin(θ₀ + θ₁ + θ₂ + θ₃) + cos(θ)⋅cos(θ₀ + θ₁ + θ₂ + θ₃) - 1  l₁⋅sin(
#
#
#                                     0
#
#
#                                                                            ⎛
# θ₀) + l₂⋅cos(θ₀ + θ₁) + l₃⋅cos(θ₀ + θ₁ + θ₂) + l₄⋅cos(θ₀ + θ₁ + θ₂ + θ₃) + ⎜-
#                                                                            ⎝
#
#
#                                                                            ⎛
# θ₀) + l₂⋅sin(θ₀ + θ₁) + l₃⋅sin(θ₀ + θ₁ + θ₂) + l₄⋅sin(θ₀ + θ₁ + θ₂ + θ₃) + ⎜-
#                                                                            ⎝
#
#
#
#
#   x      ⎛  x⋅sin(θ)    ⎞       ⎞                          ⎛  x⋅sin(θ)    ⎞
# ────── - ⎜- ──────── + y⎟⋅sin(θ)⎟⋅cos(θ₀ + θ₁ + θ₂ + θ₃) + ⎜- ──────── + y⎟⋅si
# cos(θ)   ⎝   cos(θ)     ⎠       ⎠                          ⎝   cos(θ)     ⎠
#
#
#   x      ⎛  x⋅sin(θ)    ⎞       ⎞                          ⎛  x⋅sin(θ)    ⎞
# ────── - ⎜- ──────── + y⎟⋅sin(θ)⎟⋅sin(θ₀ + θ₁ + θ₂ + θ₃) - ⎜- ──────── + y⎟⋅co
# cos(θ)   ⎝   cos(θ)     ⎠       ⎠                          ⎝   cos(θ)     ⎠
#
#          0
#
#                            ⎤
#                            ⎥
# n(θ₀ + θ₁ + θ₂ + θ₃)⋅cos(θ)⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
# s(θ)⋅cos(θ₀ + θ₁ + θ₂ + θ₃)⎥
#                            ⎥
#                            ⎥
#                            ⎦

# %%
eq = [a[0] + a[1] + a[2] - theta, eq[0, 2], eq[1, 2]]
eq
# Out:
# ⎡
# ⎢-θ + θ₀ + θ₁ + θ₂, l₁⋅cos(θ₀) + l₂⋅cos(θ₀ + θ₁) + l₃⋅cos(θ₀ + θ₁ + θ₂) + l₄⋅c
# ⎣
#
#                         ⎛    x      ⎛  x⋅sin(θ)    ⎞       ⎞
# os(θ₀ + θ₁ + θ₂ + θ₃) + ⎜- ────── - ⎜- ──────── + y⎟⋅sin(θ)⎟⋅cos(θ₀ + θ₁ + θ₂
#                         ⎝  cos(θ)   ⎝   cos(θ)     ⎠       ⎠
#
#         ⎛  x⋅sin(θ)    ⎞
# + θ₃) + ⎜- ──────── + y⎟⋅sin(θ₀ + θ₁ + θ₂ + θ₃)⋅cos(θ), l₁⋅sin(θ₀) + l₂⋅sin(θ₀
#         ⎝   cos(θ)     ⎠
#
#                                                             ⎛    x      ⎛  x⋅s
#  + θ₁) + l₃⋅sin(θ₀ + θ₁ + θ₂) + l₄⋅sin(θ₀ + θ₁ + θ₂ + θ₃) + ⎜- ────── - ⎜- ───
#                                                             ⎝  cos(θ)   ⎝   co
#
# in(θ)    ⎞       ⎞                          ⎛  x⋅sin(θ)    ⎞
# ───── + y⎟⋅sin(θ)⎟⋅sin(θ₀ + θ₁ + θ₂ + θ₃) - ⎜- ──────── + y⎟⋅cos(θ)⋅cos(θ₀ + θ
# s(θ)     ⎠       ⎠                          ⎝   cos(θ)     ⎠
#
#             ⎤
# ₁ + θ₂ + θ₃)⎥
#             ⎦

# %%
solve(eq, a)  # sympy is too stupid to solve it

# %%
b = [symbols('theta_%d' % i) for i in range(N)]
T3 = trans(x, y, theta) * trans(l[3], 0, 0).inv()
l_1_2 = T3[0,-1] ** 2 + T3[1,-1] ** 2
b_1_2 = acos((l[1] ** 2 + l[2] ** 2 - l_1_2) / (2 * l[1] * l[2]))  # cosine rule
b[1] = pi - b_1_2
b_1 = acos((l[1] ** 2 - l[2] ** 2 + l_1_2) / (2 * l[1] * sqrt(l_1_2)))  # cosine rule
b_0 = atan(T3[1,-1] / T3[0,-1])
b[0] = b_0 - b_1
b[2] = atan(T3[1,0] / T3[0,0]) - b[0] - b[1]
B = matrix([b]).T
B = simplify(B)
B
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}- {acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}{2 l_{1} \sqrt{\left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}} \right )} + {atan}{\left (\frac{l_{3} \sin{\left (\theta \right )} - y}{l_{3} \cos{\left (\theta \right )} - x} \right )}\\- {acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} - \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}\right) \right )} + \pi\\{acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \right )} + {acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} + {atan}{\left (\tan{\left (\theta \right )} \right )} - \pi\\\theta_{3}\end{smallmatrix}\right]
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡                                             ⎛  2     2                  2
# ⎢                                             ⎜l₁  - l₂  + (l₃⋅sin(θ) - y)  +
# ⎢                                       -     ⎜───────────────────────────────
# ⎢                                             ⎜         ______________________
# ⎢                                         acos⎜        ╱                2
# ⎢                                             ⎝ 2⋅l₁⋅╲╱  (l₃⋅sin(θ) - y)  + (l
# ⎢
# ⎢                                                      ⎛  2     2
# ⎢                                                      ⎜l₁  + l₂  - (l₃⋅sin(θ)
# ⎢                                                - acos⎜──────────────────────
# ⎢                                                      ⎝                    2⋅
# ⎢
# ⎢    ⎛  2     2                   2                   2⎞       ⎛  2     2
# ⎢    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-
# ⎢acos⎜─────────────────────────────────────────────────⎟ +     ⎜──────────────
# ⎢    ⎝                     2⋅l₁⋅l₂                     ⎠       ⎜         _____
# ⎢                                                          acos⎜        ╱
# ⎢                                                              ⎝ 2⋅l₁⋅╲╱  (-l₃
# ⎢
# ⎣                                                                            θ
#
#                2⎞
# (l₃⋅cos(θ) - x) ⎟       ⎛l₃⋅sin(θ) - y⎞
# ────────────────⎟ + atan⎜─────────────⎟
# _______________ ⎟       ⎝l₃⋅cos(θ) - x⎠
#              2  ⎟
# ₃⋅cos(θ) - x)   ⎠
#
#      2                  2⎞
#  - y)  - (l₃⋅cos(θ) - x) ⎟
# ─────────────────────────⎟ + π
# l₁⋅l₂                    ⎠
#
#               2                   2⎞
# l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞
# ───────────────────────────────────⎟ - atan⎜──────────────⎟ + atan(tan(θ)) - π
# __________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠
#             2                   2  ⎟
# ⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
# ₃
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
print latex(B)
# Out:
# \left[\begin{matrix}- \operatorname{acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}{2 l_{1} \sqrt{\left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}} \right )} + \operatorname{atan}{\left (\frac{l_{3} \sin{\left (\theta \right )} - y}{l_{3} \cos{\left (\theta \right )} - x} \right )}\\- \operatorname{acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} - \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}\right) \right )} + \pi\\\operatorname{acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \right )} + \operatorname{acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - \operatorname{atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} + \operatorname{atan}{\left (\tan{\left (\theta \right )} \right )} - \pi\\\theta_{3}\end{matrix}\right]

# %%
T_new = forward_kinematics(T0, l, b)
Te_new = T_new[-1]
Te_new
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alex/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _print_latex_png(o)
#     125                 if latex_mode != 'inline':
#     126                     s = latex(o, mode='inline')
# --> 127                 return _matplotlib_wrapper(s)
#     128
#     129     def _print_latex_matplotlib(o):
#
# /home/alex/.local/lib/python2.7/site-packages/sympy/interactive/printing.pyc in _matplotlib_wrapper(o)
#      88         o = o.replace(r'\operatorname', '')
#      89         o = o.replace(r'\overline', r'\bar')
# ---> 90         return latex_to_png(o)
#      91
#      92     def _can_print_latex(o):
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png(s, encode, backend, wrap)
#      85     else:
#      86         raise ValueError('No such backend {0}'.format(backend))
# ---> 87     bin_data = f(s, wrap)
#      88     if encode and bin_data:
#      89         bin_data = encodestring(bin_data)
#
# /home/alex/.local/lib/python2.7/site-packages/IPython/lib/latextools.pyc in latex_to_png_mpl(s, wrap)
#     104     mt = mathtext.MathTextParser('bitmap')
#     105     f = BytesIO()
# --> 106     mt.to_png(f, s, fontsize=12)
#     107     return f.getvalue()
#     108
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_png(self, filename, texstr, color, dpi, fontsize)
#    3092         image in pixels.
#    3093         """
# -> 3094         rgba, depth = self.to_rgba(texstr, color=color, dpi=dpi, fontsize=fontsize)
#    3095         numrows, numcols, tmp = rgba.shape
#    3096         _png.write_png(rgba.tostring(), numcols, numrows, filename)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_rgba(self, texstr, color, dpi, fontsize)
#    3057             image in pixels.
#    3058         """
# -> 3059         x, depth = self.to_mask(texstr, dpi=dpi, fontsize=fontsize)
#    3060
#    3061         r, g, b = mcolors.colorConverter.to_rgb(color)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in to_mask(self, texstr, dpi, fontsize)
#    3030         assert(self._output=="bitmap")
#    3031         prop = FontProperties(size=fontsize)
# -> 3032         ftimage, depth = self.parse(texstr, dpi=dpi, prop=prop)
#    3033
#    3034         x = ftimage.as_array()
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3003             self.__class__._parser = Parser()
#    3004
# -> 3005         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3006         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3007         result = font_output.get_results(box)
#
# /usr/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2337                         err.line,
#    2338                         " " * (err.column - 1) + "^",
# -> 2339                         six.text_type(err)]))
#    2340         self._state_stack = None
#    2341         self._em_width_cache = {}
#
# ValueError:
# \left[\begin{smallmatrix}\left(\left(\sqrt{1 - \frac{1}{4 l_{1}^{2} l_{2}^{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right)^{2}} \sin{\left ({acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} \right )} - \frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \cos{\left ({acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} \right )}\right) \sin{\left ({acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \right )} + {acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} + {atan}{\left (\frac{\sin{\left (\theta \right )}}{\cos{\left (\theta \right )}} \right )} \right )} - \left(- \sqrt{1 - \frac{1}{4 l_{1}^{2} l_{2}^{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right)^{2}} \cos{\left ({acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} \right )} - \frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \sin{\left ({acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} \right )}\right) \cos{\left ({acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \right )} + {acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - {atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} + {atan}{\l ...
#       ^
# Expected "\right" (at char 6), (line:1, col:7)
# ⎡⎛⎛
# ⎢⎜⎜
# ⎢⎜⎜       __________________________________________________________
# ⎢⎜⎜      ╱                                                        2
# ⎢⎜⎜     ╱      ⎛  2     2                   2                   2⎞      ⎛    ⎛
# ⎢⎜⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜
# ⎢⎜⎜   ╱    1 - ──────────────────────────────────────────────────── ⋅   ⎜    ⎜
# ⎢⎜⎜  ╱                                  2   2                           ⎜    ⎜
# ⎢⎜⎜╲╱                               4⋅l₁ ⋅l₂                         sin⎜acos⎜
# ⎢⎝⎝                                                                     ⎝    ⎝
# ⎢
# ⎢ ⎛  ⎛
# ⎢ ⎜  ⎜
# ⎢ ⎜  ⎜       __________________________________________________________
# ⎢ ⎜  ⎜      ╱                                                        2
# ⎢ ⎜  ⎜     ╱      ⎛  2     2                   2                   2⎞      ⎛
# ⎢ ⎜  ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜
# ⎢ ⎜- ⎜   ╱    1 - ──────────────────────────────────────────────────── ⋅   ⎜
# ⎢ ⎜  ⎜  ╱                                  2   2                           ⎜
# ⎢ ⎜  ⎜╲╱                               4⋅l₁ ⋅l₂                         sin⎜ac
# ⎢ ⎝  ⎝                                                                     ⎝
# ⎢
# ⎣
#
#
#                                                                              ⎛
#                                                                              ⎝
#
#   2     2                   2                   2⎞                       ⎞
# l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────────────────────────────⎟ - atan⎜──────────────⎟⎟ - ─
#          _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#         ╱                 2                   2  ⎟                       ⎟
#  2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#
#
#   ⎛  2     2                   2                   2⎞                       ⎞
#   ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
#   ⎜─────────────────────────────────────────────────⎟ - atan⎜──────────────⎟⎟
#   ⎜         _______________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
# os⎜        ╱                 2                   2  ⎟                       ⎟
#   ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                                       ⎛    ⎛  2     2
#   2     2                   2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅s
# l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜──────────────────
#                                                       ⎜    ⎜         _________
#                                                    cos⎜acos⎜        ╱
#                                                       ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#                                                                2⋅l₁⋅l₂
#
#
#
#                                                          ⎛    ⎛  2     2
#   ⎛  2     2                   2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l
#   ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜───────────────
#                                                          ⎜    ⎜         ______
#                                                       cos⎜acos⎜        ╱
#                                                          ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅
# - ────────────────────────────────────────────────────────────────────────────
#                                                                   2⋅l₁⋅l₂
#
#
#
#
#
#           2                   2⎞                       ⎞⎞
# in(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# ______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#         2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# (θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  -
# ────────────────────────────────────────────────────────⎟⋅   ⎜acos⎜───────────
#                                                         ⎟    ⎜    ⎝
#                                                         ⎟ sin⎜
#                                                         ⎠    ⎝
#
#              2                   2⎞                       ⎞⎞
# ₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ──────────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# _________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#            2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2
# sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂
# ───────────────────────────────────────────────────────────⎟⋅   ⎜acos⎜────────
#                                                            ⎟    ⎜    ⎝
#                                                            ⎟ sin⎜
#                                                            ⎠    ⎝
#
#
#
#
#
#
#
#                  2                   2⎞       ⎛  2     2                   2
#  (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  +
# ──────────────────────────────────────⎟ +     ⎜───────────────────────────────
#           2⋅l₁⋅l₂                     ⎠       ⎜         ______________________
#                                           acos⎜        ╱                 2
#                                               ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (
#
#
#
#
#
# 2                   2                   2⎞       ⎛  2     2
#   - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)
# ─────────────────────────────────────────⎟ +     ⎜────────────────────────────
#              2⋅l₁⋅l₂                     ⎠       ⎜         ___________________
#                                              acos⎜        ╱                 2
#                                                  ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)
#
#
#
#                                                              ⎛
#                                                              ⎜
#                                                              ⎜         _______
#                                                              ⎜        ╱
#                  2⎞                                      ⎞   ⎜       ╱      ⎛
#  (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱       ⎝l
# ──────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1 - ──
# _________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱
#                2  ⎟                                      ⎟   ⎜  ╲╱
# -l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#                                                                 ⎛
#                                                                 ⎜
#                                                                 ⎜       ______
#                                                                 ⎜      ╱
# 2                   2⎞                                      ⎞   ⎜     ╱      ⎛
#   + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱       ⎝
# ─────────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜   ╱    1 - ─
# ____________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱
#                   2  ⎟                                      ⎟   ⎜╲╱
# + (-l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#
#
#
#
# ___________________________________________________
#                                                  2
#  2     2                   2                   2⎞      ⎛    ⎛  2     2
# ₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅
# ────────────────────────────────────────────────── ⋅   ⎜    ⎜─────────────────
#                        2   2                           ⎜    ⎜         ________
#                    4⋅l₁ ⋅l₂                         cos⎜acos⎜        ╱
#                                                        ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅si
#
#
#
# ____________________________________________________
#                                                   2
#   2     2                   2                   2⎞      ⎛    ⎛  2     2
# l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃
# ─────────────────────────────────────────────────── ⋅   ⎜    ⎜────────────────
#                         2   2                           ⎜    ⎜         _______
#                     4⋅l₁ ⋅l₂                         cos⎜acos⎜        ╱
#                                                         ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅s
#
#
#
#
#                                                             ⎛  2     2
#                                                             ⎝l₁  + l₂  - (-l₃⋅
#
#            2                   2⎞                       ⎞
# sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ────────────────────────────────⎟ - atan⎜──────────────⎟⎟ - ──────────────────
# _______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#          2                   2  ⎟                       ⎟
# n(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#                                                              ⎛  2     2
#                                                              ⎝l₁  + l₂  - (-l₃
#
#             2                   2⎞                       ⎞
# ⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────────────⎟ - atan⎜──────────────⎟⎟ + ─────────────────
# ________________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#           2                   2  ⎟                       ⎟
# in(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                      ⎛    ⎛  2     2                   2
#            2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l
# sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜───────────────────────────────────
#                                      ⎜    ⎜         __________________________
#                                   sin⎜acos⎜        ╱                 2
#                                      ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                               2⋅l₁⋅l₂
#
#
#
#                                       ⎛    ⎛  2     2                   2
#             2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-
# ⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜──────────────────────────────────
#                                       ⎜    ⎜         _________________________
#                                    sin⎜acos⎜        ╱                 2
#                                       ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃
# ──────────────────────────────────────────────────────────────────────────────
#                                                2⋅l₁⋅l₂
#
#
#
#
#
#              2⎞                       ⎞⎞
# ₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ──────────────⎟ - atan⎜──────────────⎟⎟⎟
# _____________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#            2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)
# ───────────────────────────────────────⎟⋅   ⎜acos⎜────────────────────────────
#                                        ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                        ⎟ cos⎜
#                                        ⎠    ⎝
#
#               2⎞                       ⎞⎞
# l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────⎟ - atan⎜──────────────⎟⎟⎟
# ______________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#             2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# ⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y
# ────────────────────────────────────────⎟⋅   ⎜acos⎜───────────────────────────
#                                         ⎟    ⎜    ⎝                     2⋅l₁⋅l
#                                         ⎟ cos⎜
#                                         ⎠    ⎝
#
#
#
#
#
#
#
# 2                   2⎞       ⎛  2     2                   2
#   - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
# ─────────────────────⎟ +     ⎜────────────────────────────────────────────────
#                      ⎠       ⎜         _______________________________________
#                          acos⎜        ╱                 2                   2
#                              ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
#
#
#
#
#
#  2                   2⎞       ⎛  2     2                   2
# )  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x
# ──────────────────────⎟ +     ⎜───────────────────────────────────────────────
# ₂                     ⎠       ⎜         ______________________________________
#                           acos⎜        ╱                 2                   2
#                               ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
#
#
#
#                                          ⎞           ⎛  ⎛
#                                          ⎟           ⎜  ⎜
#                                          ⎟           ⎜  ⎜       ______________
#                                          ⎟           ⎜  ⎜      ╱
# 2⎞                                      ⎞⎟           ⎜  ⎜     ╱      ⎛  2
#  ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟           ⎜  ⎜    ╱       ⎝l₁  + l₂
# ─⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⋅sin(θ₃) + ⎜- ⎜   ╱    1 - ─────────
#  ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟           ⎜  ⎜  ╱
#  ⎟                                      ⎟⎟           ⎜  ⎜╲╱
#  ⎠                                      ⎠⎠           ⎝  ⎝
#
#                                           ⎞           ⎛  ⎛
#                                           ⎟           ⎜  ⎜
#                                           ⎟           ⎜  ⎜       _____________
#                                           ⎟           ⎜  ⎜      ╱
#  2⎞                                      ⎞⎟           ⎜  ⎜     ╱      ⎛  2
# ) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟           ⎜  ⎜    ╱       ⎝l₁  + l
# ──⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⋅cos(θ₃) + ⎜- ⎜   ╱    1 - ────────
# _ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟           ⎜  ⎜  ╱
#   ⎟                                      ⎟⎟           ⎜  ⎜╲╱
#   ⎠                                      ⎠⎠           ⎝  ⎝
#
#                                                     0
#
#
#
# ____________________________________________
#                                           2
# 2                   2                   2⎞      ⎛    ⎛  2     2
#   - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ)
# ─────────────────────────────────────────── ⋅   ⎜    ⎜────────────────────────
#                 2   2                           ⎜    ⎜         _______________
#             4⋅l₁ ⋅l₂                         sin⎜acos⎜        ╱
#                                                 ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) +
#
#
#
# _____________________________________________
#                                            2
#  2                   2                   2⎞      ⎛    ⎛  2     2
# ₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ)
# ──────────────────────────────────────────── ⋅   ⎜    ⎜───────────────────────
#                  2   2                           ⎜    ⎜         ______________
#              4⋅l₁ ⋅l₂                         sin⎜acos⎜        ╱
#                                                  ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) +
#
#
#
#
#                                                      ⎛  2     2
#                                                      ⎝l₁  + l₂  - (-l₃⋅sin(θ)
#
#     2                   2⎞                       ⎞
# + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ─────────────────────────⎟ - atan⎜──────────────⎟⎟ - ─────────────────────────
# ________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#   2                   2  ⎟                       ⎟
# y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#                                                       ⎛  2     2
#                                                       ⎝l₁  + l₂  - (-l₃⋅sin(θ)
#
#      2                   2⎞                       ⎞
#  + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ──────────────────────────⎟ - atan⎜──────────────⎟⎟ - ────────────────────────
# _________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#    2                   2  ⎟                       ⎟
#  y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                               ⎛    ⎛  2     2                   2
#     2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ
# + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜──────────────────────────────────────────
#                               ⎜    ⎜         _________________________________
#                            cos⎜acos⎜        ╱                 2
#                               ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
# ──────────────────────────────────────────────────────────────────────────────
#                                        2⋅l₁⋅l₂
#
#
#
#                                ⎛    ⎛  2     2                   2
#      2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(
#  + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜─────────────────────────────────────────
#                                ⎜    ⎜         ________________________________
#                             cos⎜acos⎜        ╱                 2
#                                ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
# ──────────────────────────────────────────────────────────────────────────────
#                                         2⋅l₁⋅l₂
#
#
#
#
#
#       2⎞                       ⎞⎞
# ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────⎟ - atan⎜──────────────⎟⎟⎟
# ______ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#     2  ⎟                       ⎟⎟    ⎛    ⎛  2     2                   2
# + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l
# ────────────────────────────────⎟⋅   ⎜acos⎜───────────────────────────────────
#                                 ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                 ⎟ cos⎜
#                                 ⎠    ⎝
#
#        2⎞                       ⎞⎞
# θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ────────⎟ - atan⎜──────────────⎟⎟⎟
# _______ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#      2  ⎟                       ⎟⎟    ⎛    ⎛  2     2                   2
#  + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-
# ─────────────────────────────────⎟⋅   ⎜acos⎜──────────────────────────────────
#                                  ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                  ⎟ cos⎜
#                                  ⎠    ⎝
#
#
#
#
#
#
#
#              2⎞       ⎛  2     2                   2                   2⎞
# ₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ──────────────⎟ +     ⎜─────────────────────────────────────────────────⎟ - at
#               ⎠       ⎜         _______________________________________ ⎟
#                   acos⎜        ╱                 2                   2  ⎟
#                       ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#
#
#               2⎞       ⎛  2     2                   2                   2⎞
# l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ───────────────⎟ +     ⎜─────────────────────────────────────────────────⎟ - a
#                ⎠       ⎜         _______________________________________ ⎟
#                    acos⎜        ╱                 2                   2  ⎟
#                        ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#                                      ⎛
#                                      ⎜
#                                      ⎜         _______________________________
#                                      ⎜        ╱
#                                  ⎞   ⎜       ╱      ⎛  2     2
#   ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) +
# an⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1 - ──────────────────────────
#   ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱                                  2
#                                  ⎟   ⎜  ╲╱                               4⋅l₁
#                                  ⎠   ⎝
#
#                                       ⎛
#                                       ⎜
#                                       ⎜       ________________________________
#                                       ⎜      ╱
#                                   ⎞   ⎜     ╱      ⎛  2     2
#    ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱       ⎝l₁  + l₂  - (-l₃⋅sin(θ) +
# tan⎜──────────────⎟ + atan⎜──────⎟⎟ + ⎜   ╱    1 - ───────────────────────────
#    ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱                                  2
#                                   ⎟   ⎜╲╱                               4⋅l₁ ⋅
#                                   ⎠   ⎝
#
#
#
#
#
# ___________________________
#                          2
#    2                   2⎞      ⎛    ⎛  2     2                   2
#  y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(
# ────────────────────────── ⋅   ⎜    ⎜─────────────────────────────────────────
#    2                           ⎜    ⎜         ________________________________
# ⋅l₂                         cos⎜acos⎜        ╱                 2
#                                ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
#
#
#
# __________________________
#                         2
#   2                   2⎞      ⎛    ⎛  2     2                   2
# y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ
# ───────────────────────── ⋅   ⎜    ⎜──────────────────────────────────────────
#   2                           ⎜    ⎜         _________________________________
# l₂                         cos⎜acos⎜        ╱                 2
#                               ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ)
#
#
#
#
#                                     ⎛  2     2                   2
#                                     ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(
#
#        2⎞                       ⎞
# θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ────────⎟ - atan⎜──────────────⎟⎟ - ──────────────────────────────────────────
# _______ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#      2  ⎟                       ⎟
#  + x)   ⎠                       ⎠
#
#
#                                    ⎛  2     2                   2
#                                    ⎝l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ
#
#       2⎞                       ⎞
# ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ───────⎟ - atan⎜──────────────⎟⎟ + ───────────────────────────────────────────
# ______ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#     2  ⎟                       ⎟
# + x)   ⎠                       ⎠
#
#
#
#              ⎛    ⎛  2     2                   2                   2⎞
#        2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-
# θ) + x) ⎠⋅   ⎜    ⎜─────────────────────────────────────────────────⎟ - atan⎜─
#              ⎜    ⎜         _______________________________________ ⎟       ⎝-
#           sin⎜acos⎜        ╱                 2                   2  ⎟
#              ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                       2⋅l₁⋅l₂
#
#
#
#             ⎛    ⎛  2     2                   2                   2⎞
#       2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l
# ) + x) ⎠⋅   ⎜    ⎜─────────────────────────────────────────────────⎟ - atan⎜──
#             ⎜    ⎜         _______________________________________ ⎟       ⎝-l
#          sin⎜acos⎜        ╱                 2                   2  ⎟
#             ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                      2⋅l₁⋅l₂
#
#
#
#
#
#               ⎞⎞
# l₃⋅sin(θ) + y⎞⎟⎟
# ─────────────⎟⎟⎟
# l₃⋅cos(θ) + x⎠⎟⎟
#               ⎟⎟    ⎛    ⎛  2     2                   2                   2⎞
#               ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟
# ───────────────⎟⋅   ⎜acos⎜─────────────────────────────────────────────────⎟ +
#                ⎟    ⎜    ⎝                     2⋅l₁⋅l₂                     ⎠
#                ⎟ sin⎜
#                ⎠    ⎝
#
#              ⎞⎞
# ₃⋅sin(θ) + y⎞⎟⎟
# ────────────⎟⎟⎟
# ₃⋅cos(θ) + x⎠⎟⎟
#              ⎟⎟    ⎛    ⎛  2     2                   2                   2⎞
#              ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟
# ──────────────⎟⋅   ⎜acos⎜─────────────────────────────────────────────────⎟ +
#               ⎟    ⎜    ⎝                     2⋅l₁⋅l₂                     ⎠
#               ⎟ sin⎜
#               ⎠    ⎝
#
#
#
#
#
#
#
#      ⎛  2     2                   2                   2⎞
#      ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y
# ...
#
#
#
#
#          2                   2⎞                       ⎞⎞
# n(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ──────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# _____________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#        2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  -
# ───────────────────────────────────────────────────────⎟⋅   ⎜acos⎜────────────
#                                                        ⎟    ⎜    ⎝
#                                                        ⎟ cos⎜
#                                                        ⎠    ⎝
#
#           2                   2⎞                       ⎞⎞
# in(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ───────────────────────────────⎟ - atan⎜──────────────⎟⎟⎟
# ______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#         2                   2  ⎟                       ⎟⎟    ⎛    ⎛  2     2
# (θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  -
# ────────────────────────────────────────────────────────⎟⋅   ⎜acos⎜───────────
#                                                         ⎟    ⎜    ⎝
#                                                         ⎟ cos⎜
#                                                         ⎠    ⎝
#
#
#
#
#
#
#
#                 2                   2⎞       ⎛  2     2                   2
# (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  +
# ─────────────────────────────────────⎟ +     ⎜────────────────────────────────
#          2⋅l₁⋅l₂                     ⎠       ⎜         _______________________
#                                          acos⎜        ╱                 2
#                                              ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-
#
#
#
#
#
#                  2                   2⎞       ⎛  2     2                   2
#  (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  +
# ──────────────────────────────────────⎟ +     ⎜───────────────────────────────
#           2⋅l₁⋅l₂                     ⎠       ⎜         ______________________
#                                           acos⎜        ╱                 2
#                                               ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (
#
#
#
#                                                             ⎛
#                                                             ⎜
#                                                             ⎜         ________
#                                                             ⎜        ╱
#                 2⎞                                      ⎞   ⎜       ╱      ⎛
# (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜      ╱       ⎝l₁
# ─────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ - ⎜-    ╱    1 - ───
# ________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜    ╱
#               2  ⎟                                      ⎟   ⎜  ╲╱
# l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#                                                              ⎛
#                                                              ⎜
#                                                              ⎜       _________
#                                                              ⎜      ╱
#                  2⎞                                      ⎞   ⎜     ╱      ⎛  2
#  (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟   ⎜    ╱       ⎝l₁
# ──────────────────⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟ + ⎜   ╱    1 - ────
# _________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟   ⎜  ╱
#                2  ⎟                                      ⎟   ⎜╲╱
# -l₃⋅cos(θ) + x)   ⎠                                      ⎠   ⎝
#
#
#
#
#
# __________________________________________________
#                                                 2
# 2     2                   2                   2⎞      ⎛    ⎛  2     2
#   + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅s
# ───────────────────────────────────────────────── ⋅   ⎜    ⎜──────────────────
#                       2   2                           ⎜    ⎜         _________
#                   4⋅l₁ ⋅l₂                         cos⎜acos⎜        ╱
#                                                       ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin
#
#
#
# _________________________________________________
#                                                2
#      2                   2                   2⎞      ⎛    ⎛  2     2
#  + l₂  - (-l₃⋅sin(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠      ⎜    ⎜l₁  - l₂  + (-l₃⋅si
# ──────────────────────────────────────────────── ⋅   ⎜    ⎜───────────────────
#                      2   2                           ⎜    ⎜         __________
#                  4⋅l₁ ⋅l₂                         cos⎜acos⎜        ╱
#                                                      ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(
#
#
#
#
#                                                            ⎛  2     2
#                                                            ⎝l₁  + l₂  - (-l₃⋅s
#
#           2                   2⎞                       ⎞
# in(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ───────────────────────────────⎟ - atan⎜──────────────⎟⎟ - ───────────────────
# ______________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#         2                   2  ⎟                       ⎟
# (θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#                                                           ⎛  2     2
#                                                           ⎝l₁  + l₂  - (-l₃⋅si
#
#          2                   2⎞                       ⎞
# n(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟
# ──────────────────────────────⎟ - atan⎜──────────────⎟⎟ + ────────────────────
# _____________________________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟
#        2                   2  ⎟                       ⎟
# θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠                       ⎠
#
#
#
#                                     ⎛    ⎛  2     2                   2
#           2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃
# in(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜────────────────────────────────────
#                                     ⎜    ⎜         ___________________________
#                                  sin⎜acos⎜        ╱                 2
#                                     ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                                              2⋅l₁⋅l₂
#
#
#
#                                    ⎛    ⎛  2     2                   2
#          2                   2⎞    ⎜    ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅
# n(θ) + y)  - (-l₃⋅cos(θ) + x) ⎠⋅   ⎜    ⎜─────────────────────────────────────
#                                    ⎜    ⎜         ____________________________
#                                 sin⎜acos⎜        ╱                 2
#                                    ⎝    ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅co
# ──────────────────────────────────────────────────────────────────────────────
#                                             2⋅l₁⋅l₂
#
#
#
#
#
#             2⎞                       ⎞⎞
# ⋅cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ─────────────⎟ - atan⎜──────────────⎟⎟⎟
# ____________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#           2  ⎟                       ⎟⎟    ⎛    ⎛  2     2                   2
# os(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)
# ──────────────────────────────────────⎟⋅   ⎜acos⎜─────────────────────────────
#                                       ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                       ⎟ sin⎜
#                                       ⎠    ⎝
#
#            2⎞                       ⎞⎞
# cos(θ) + x) ⎟       ⎛-l₃⋅sin(θ) + y⎞⎟⎟
# ────────────⎟ - atan⎜──────────────⎟⎟⎟
# ___________ ⎟       ⎝-l₃⋅cos(θ) + x⎠⎟⎟
#          2  ⎟                       ⎟⎟    ⎛    ⎛  2     2                   2
# s(θ) + x)   ⎠                       ⎠⎟    ⎜    ⎜l₁  + l₂  - (-l₃⋅sin(θ) + y)
# ─────────────────────────────────────⎟⋅   ⎜acos⎜──────────────────────────────
#                                      ⎟    ⎜    ⎝                     2⋅l₁⋅l₂
#                                      ⎟ sin⎜
#                                      ⎠    ⎝
#
#
#
#
#
#
#
#                    2⎞       ⎛  2     2                   2                   2
#  - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
# ────────────────────⎟ +     ⎜─────────────────────────────────────────────────
#                     ⎠       ⎜         _______________________________________
#                         acos⎜        ╱                 2                   2
#                             ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)
#
#
#
#
#
#                   2⎞       ⎛  2     2                   2                   2⎞
# - (-l₃⋅cos(θ) + x) ⎟       ⎜l₁  - l₂  + (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x) ⎟
# ───────────────────⎟ +     ⎜─────────────────────────────────────────────────⎟
#                    ⎠       ⎜         _______________________________________ ⎟
#                        acos⎜        ╱                 2                   2  ⎟
#                            ⎝ 2⋅l₁⋅╲╱  (-l₃⋅sin(θ) + y)  + (-l₃⋅cos(θ) + x)   ⎠
#
#
#
#                                         ⎞        ⎞⎤
#                                         ⎟        ⎟⎥
#                                         ⎟        ⎟⎥
#                                         ⎟        ⎟⎥
# ⎞                                      ⎞⎟        ⎟⎥
# ⎟       ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟        ⎟⎥
# ⎟ - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⋅cos(θ₃)⎟⎥
# ⎟       ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟        ⎟⎥
# ⎟                                      ⎟⎟        ⎟⎥
# ⎠                                      ⎠⎠        ⎠⎥
#                                                   ⎥
#                                        ⎞        ⎞ ⎥
#                                        ⎟        ⎟ ⎥
#                                        ⎟        ⎟ ⎥
#                                        ⎟        ⎟ ⎥
#                                       ⎞⎟        ⎟ ⎥
#        ⎛-l₃⋅sin(θ) + y⎞       ⎛sin(θ)⎞⎟⎟        ⎟ ⎥
#  - atan⎜──────────────⎟ + atan⎜──────⎟⎟⎟⋅sin(θ₃)⎟ ⎥
#        ⎝-l₃⋅cos(θ) + x⎠       ⎝cos(θ)⎠⎟⎟        ⎟ ⎥
#                                       ⎟⎟        ⎟ ⎥
#                                       ⎠⎠        ⎠ ⎥
#                                                   ⎥
#                                                   ⎦

# %%
simplify(Te_new[0, 0])

# %%
simplify(Te_new[1, 0])

# %%
simplify(Te_new[0, -1])

# %% [markdown]
# ### Test the analytical solution

# %%
from numpy import sin, cos, pi, matrix
from math import atan2, acos

T0 = trans(0, 0, 0)
lv = [0] + range(N, 0, -1)  # length of link, l[0] is ingored
bf = B
for i in range(N):
    bf = bf.subs(l[i + 1], lv[i + 1])

def inverse_kinematics(x_e, y_e, theta_e):
    b = bf.subs(x, x_e).subs(y, y_e).subs(theta, theta_e)
    b = (b.subs('I', 1).subs('pi', pi).tolist())
    b = [float(i[0]) for i in b]
    return b
    
@interact(x_e=(0, max_len, 0.1), y_e=(-max_len, max_len, 0.1), theta_e=(-pi, pi, 0.1))
def set_end_effector(x_e=6, y_e=0, theta_e=0):
    b = inverse_kinematics(x_e, y_e, theta_e)
    T = forward_kinematics(T0, lv, b)
    show_robot_arm(T)

# %% [markdown]
# ### Numerical Solution

# %%
from numpy import asarray
theta = asarray([0.1] * N)
def inverse_kinematics(x_e, y_e, theta_e, theta):
    target = matrix([[x_e, y_e, theta_e]])
    while True:
        T = forward_kinematics(T0, lv, theta)
        Te = matrix([from_trans(T[-1])])
        e = target - Te
        T = matrix([from_trans(i) for i in T[1:-1]])
        J = Te - T
        J = J.T
        J[-1, :] = 1
        JJT = J * J.T
        d_theta = 0.001 * J.T * JJT.I * e.T
        #print (d_theta.T * d_theta)[0, 0]
        theta += asarray(d_theta.T)[0]
        if (d_theta.T * d_theta)[0, 0] < 1e-6:
            break
    return theta

T = forward_kinematics(T0, lv, theta)
Te = matrix([from_trans(T[-1])])

@interact(x_e=(0, max_len, 0.01), y_e=(-max_len, max_len, 0.01), theta_e=(-pi, pi, 0.01), theta=fixed(theta))
def set_end_effector(x_e=Te[0,0], y_e=Te[0,1], theta_e=Te[0,2], theta=theta):
    theta = inverse_kinematics(x_e, y_e, theta_e, theta)
    T = forward_kinematics(T0, lv, theta)
    show_robot_arm(T)
